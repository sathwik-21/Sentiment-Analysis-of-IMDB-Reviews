# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
#Sentences
sent=[
    'the glass of milk',
    'the glass of juice',
    'the cup of tea',
    'I am a good boy',
    'I am a good developer',
    'understand the meaning of words',
    'your videos are good'
]

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
#Define the vocab size
voc_size=10000

# %%
#One Hot Representation
one_hot_rep=[one_hot(words,voc_size)for words in sent]

# %%
one_hot_rep
# Out:
# [[820, 9049, 8343, 8635],
#  [820, 9049, 8343, 8542],
#  [820, 1725, 8343, 7223],
#  [4153, 9550, 8179, 5862, 6415],
#  [4153, 9550, 8179, 5862, 580],
#  [3504, 820, 7301, 8343, 8603],
#  [1809, 4961, 7019, 5862]]

# %%
#Word Embedding Representation
from tensorflow.keras.layers import Embedding
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_length=8

# %%
embedded_docs=pad_sequences(one_hot_rep,padding='pre',maxlen=sent_length)

# %%
embedded_docs
# Out:
# array([[   0,    0,    0,    0,  820, 9049, 8343, 8635],
#        [   0,    0,    0,    0,  820, 9049, 8343, 8542],
#        [   0,    0,    0,    0,  820, 1725, 8343, 7223],
#        [   0,    0,    0, 4153, 9550, 8179, 5862, 6415],
#        [   0,    0,    0, 4153, 9550, 8179, 5862,  580],
#        [   0,    0,    0, 3504,  820, 7301, 8343, 8603],
#        [   0,    0,    0,    0, 1809, 4961, 7019, 5862]], dtype=int32)

# %%
#Feature Representation
dim=10

# %%
model=Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_length))
# Out:
# c:\Users\sathwik\OneDrive\Desktop\Deep Learning\dlenv\lib\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.compile('adam','mse')

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# array([[[-0.02161198, -0.02019074,  0.01259153,  0.01852566,
#          -0.04106716, -0.00801973, -0.01704357,  0.02354845,
#           0.02787915,  0.01656971],
#         [-0.02161198, -0.02019074,  0.01259153,  0.01852566,
#          -0.04106716, -0.00801973, -0.01704357,  0.02354845,
#           0.02787915,  0.01656971],
#         [-0.02161198, -0.02019074,  0.01259153,  0.01852566,
#          -0.04106716, -0.00801973, -0.01704357,  0.02354845,
#           0.02787915,  0.01656971],
#         [-0.02161198, -0.02019074,  0.01259153,  0.01852566,
#          -0.04106716, -0.00801973, -0.01704357,  0.02354845,
#           0.02787915,  0.01656971],
#         [ 0.00374101, -0.02233263,  0.04831837,  0.02469764,
#          -0.02574922, -0.03991247, -0.01748685, -0.04859419,
#          -0.04150964, -0.03108046],
#         [-0.02346162,  0.01968512,  0.01738702,  0.01945559,
#          -0.0206216 ,  0.04413802, -0.02889305,  0.01923999,
#           0.00437988,  0.02591716],
#         [ 0.04999569,  0.03412998, -0.04870277, -0.04430515,
#          -0.02356807, -0.03139988, -0.04346138,  0.03044787,
#          -0.02157257, -0.0484942 ],
#         [-0.03665775,  0.02301887, -0.04088435,  0.01218555,
#           0.0240528 ,  0.02080275, -0.01908793,  0.00496559,
#          -0.003584  , -0.02379553]],
#
#        [[-0.02161198, -0.02019074,  0.01259153,  0.01852566,
#          -0.04106716, -0.00801973, -0.01704357,  0.02354845,
#           0.02787915,  0.01656971],
#         [-0.02161198, -0.02019074,  0.01259153,  0.01852566,
#          -0.04106716, -0.00801973, -0.01704357,  0.02354845,
#           0.02787915,  0.01656971],
#         [-0.02161198, -0.02019074,  0.01259153,  0.01852566,
#          -0.04106716, -0.00801973, -0.01704357,  0.02354845,
#           0.02787915,  0.01656971],
#         [-0.02161198, -0.02019074,  0.01259153,  0.01852566,
#          -0.04106716, -0.00801973, -0.01704357,  0.02354845,
#           0.02787915,  0.01656971],
#         [ 0.00374101, -0.02233263,  0.04831837,  0.02469764,
#          -0.02574922, -0.03991247, -0.01748685, -0.04859419,
#          -0.04150964, -0.03108046],
#         [-0.02346162,  0.01968512,  0.01738702,  0.01945559,
#          -0.0206216 ,  0.04413802, -0.02889305,  0.01923999,
#           0.00437988,  0.02591716],
#         [ 0.04999569,  0.03412998, -0.04870277, -0.04430515,
#          -0.02356807, -0.03139988, -0.04346138,  0.03044787,
#          -0.02157257, -0.0484942 ],
#         [ 0.03368144,  0.04880119,  0.02524218,  0.01674464,
#          -0.01221465, -0.04285179,  0.00759766,  0.00401505,
#          -0.0084748 , -0.00451007]],
#
#        [[-0.02161198, -0.02019074,  0.01259153,  0.01852566,
#          -0.04106716, -0.00801973, -0.01704357,  0.02354845,
#           0.02787915,  0.01656971],
#         [-0.02161198, -0.02019074,  0.01259153,  0.01852566,
#          -0.04106716, -0.00801973, -0.01704357,  0.02354845,
#           0.02787915,  0.01656971],
#         [-0.02161198, -0.02019074,  0.01259153,  0.01852566,
#          -0.04106716, -0.00801973, -0.01704357,  0.02354845,
#           0.02787915,  0.01656971],
#         [-0.02161198, -0.02019074,  0.01259153,  0.01852566,
#          -0.04106716, -0.00801973, -0.01704357,  0.02354845,
#           0.02787915,  0.01656971],
#         [ 0.00374101, -0.02233263,  0.04831837,  0.02469764,
#          -0.02574922, -0.03991247, -0.01748685, -0.04859419,
#          -0.04150964, -0.03108046],
#         [ 0.03013207, -0.03471871,  0.00408443,  0.00144584,
#           0.03010926,  0.00988617, -0.03571469,  0.02244581,
#           0.01010116, -0.00439249],
#         [ 0.04999569,  0.03412998, -0.04870277, -0.04430515,
#          -0.02356807, -0.03139988, -0.04346138,  0.03044787,
#          -0.02157257, -0.0484942 ],
#         [ 0.02057643, -0.01955655,  0.03408333,  0.04938755,
#          -0.01496308,  0.01980117,  0.02583199,  0.02519158,
#          -0.01197731,  0.0322911 ]],
#
#        [[-0.02161198, -0.02019074,  0.01259153,  0.01852566,
#          -0.04106716, -0.00801973, -0.01704357,  0.02354845,
#           0.02787915,  0.01656971],
#         [-0.02161198, -0.02019074,  0.01259153,  0.01852566,
#          -0.04106716, -0.00801973, -0.01704357,  0.02354845,
#           0.02787915,  0.01656971],
#         [-0.02161198, -0.02019074,  0.01259153,  0.01852566,
#          -0.04106716, -0.00801973, -0.01704357,  0.02354845,
#           0.02787915,  0.01656971],
#         [ 0.00329703,  0.04434762,  0.02464725, -0.03847258,
#           0.00060841, -0.0103155 ,  0.04025208,  0.01877186,
#           0.02520475, -0.02496605],
#         [ 0.0220359 , -0.025772  , -0.01872896,  0.03777253,
#           0.02822525, -0.03457899, -0.0454853 , -0.01558914,
#          -0.00678313, -0.0228242 ],
#         [-0.02477598, -0.00804108,  0.02369786,  0.03658617,
#           0.0272163 ,  0.014103  , -0.04257848,  0.02721542,
#          -0.0083416 ,  0.00676315],
#         [ 0.02495218,  0.02812736,  0.04806237,  0.0042673 ,
#           0.01563014, -0.03796985,  0.0451961 , -0.00305261,
#           0.02571243,  0.01259109],
#         [-0.02292385,  0.02797193,  0.02349601,  0.04760465,
#           0.0165933 ,  0.04559109,  0.04412545,  0.04393193,
#          -0.03224635, -0.03514237]],
#
#        [[-0.02161198, -0.02019074,  0.01259153,  0.01852566,
#          -0.04106716, -0.00801973, -0.01704357,  0.02354845,
#           0.02787915,  0.01656971],
#         [-0.02161198, -0.02019074,  0.01259153,  0.01852566,
#          -0.04106716, -0.00801973, -0.01704357,  0.02354845,
#           0.02787915,  0.01656971],
#         [-0.02161198, -0.02019074,  0.01259153,  0.01852566,
#          -0.04106716, -0.00801973, -0.01704357,  0.02354845,
#           0.02787915,  0.01656971],
#         [ 0.00329703,  0.04434762,  0.02464725, -0.03847258,
#           0.00060841, -0.0103155 ,  0.04025208,  0.01877186,
#           0.02520475, -0.02496605],
#         [ 0.0220359 , -0.025772  , -0.01872896,  0.03777253,
#           0.02822525, -0.03457899, -0.0454853 , -0.01558914,
#          -0.00678313, -0.0228242 ],
#         [-0.02477598, -0.00804108,  0.02369786,  0.03658617,
#           0.0272163 ,  0.014103  , -0.04257848,  0.02721542,
#          -0.0083416 ,  0.00676315],
#         [ 0.02495218,  0.02812736,  0.04806237,  0.0042673 ,
#           0.01563014, -0.03796985,  0.0451961 , -0.00305261,
#           0.02571243,  0.01259109],
#         [-0.00417386, -0.03428832,  0.04338301, -0.02425511,
#           0.04073883, -0.0106901 ,  0.00768324, -0.00109887,
#           0.01710861, -0.03712763]],
#
#        [[-0.02161198, -0.02019074,  0.01259153,  0.01852566,
#          -0.04106716, -0.00801973, -0.01704357,  0.02354845,
#           0.02787915,  0.01656971],
#         [-0.02161198, -0.02019074,  0.01259153,  0.01852566,
#          -0.04106716, -0.00801973, -0.01704357,  0.02354845,
#           0.02787915,  0.01656971],
#         [-0.02161198, -0.02019074,  0.01259153,  0.01852566,
#          -0.04106716, -0.00801973, -0.01704357,  0.02354845,
#           0.02787915,  0.01656971],
#         [ 0.03425943, -0.02121525, -0.01067873, -0.04568844,
#           0.03550376, -0.02217625, -0.04338333, -0.04193889,
#           0.00299032,  0.00420039],
#         [ 0.00374101, -0.02233263,  0.04831837,  0.02469764,
#          -0.02574922, -0.03991247, -0.01748685, -0.04859419,
#          -0.04150964, -0.03108046],
#         [-0.03589754,  0.02180947,  0.00684015, -0.02704058,
#          -0.00072837,  0.04568478, -0.01672034,  0.02678907,
#          -0.02885809,  0.01487989],
#         [ 0.04999569,  0.03412998, -0.04870277, -0.04430515,
#          -0.02356807, -0.03139988, -0.04346138,  0.03044787,
#          -0.02157257, -0.0484942 ],
#         [-0.00776481, -0.00235387,  0.02804467,  0.04439291,
#          -0.01383444, -0.03373658,  0.02108923,  0.01191271,
#          -0.04009648,  0.04638258]],
#
#        [[-0.02161198, -0.02019074,  0.01259153,  0.01852566,
#          -0.04106716, -0.00801973, -0.01704357,  0.02354845,
#           0.02787915,  0.01656971],
#         [-0.02161198, -0.02019074,  0.01259153,  0.01852566,
#          -0.04106716, -0.00801973, -0.01704357,  0.02354845,
#           0.02787915,  0.01656971],
#         [-0.02161198, -0.02019074,  0.01259153,  0.01852566,
#          -0.04106716, -0.00801973, -0.01704357,  0.02354845,
#           0.02787915,  0.01656971],
#         [-0.02161198, -0.02019074,  0.01259153,  0.01852566,
#          -0.04106716, -0.00801973, -0.01704357,  0.02354845,
#           0.02787915,  0.01656971],
#         [-0.02512897,  0.03836491,  0.00428683, -0.02603613,
#           0.04084635,  0.02038435,  0.0367448 , -0.00650365,
#           0.02046449, -0.03951376],
#         [ 0.04507512,  0.01446072,  0.01001663,  0.00032375,
#          -0.00876439, -0.01754193,  0.0278774 , -0.00931279,
#          -0.02622168, -0.01180543],
#         [ 0.04402066, -0.03328516,  0.02427818, -0.01997467,
#          -0.00619582, -0.04339522, -0.04554287,  0.01777107,
#          -0.02507832, -0.04183277],
#         [ 0.02495218,  0.02812736,  0.04806237,  0.0042673 ,
#           0.01563014, -0.03796985,  0.0451961 , -0.00305261,
#           0.02571243,  0.01259109]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0,  820, 9049, 8343, 8635], dtype=int32)
